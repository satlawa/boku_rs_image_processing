# %%
#First import all needed modules
import sentinelhub
import datetime

# %%
#specify tiles, for example two in the eastern part of Austria:
tiles = ["T33UXP"]

#specify start and end date (here we use May 2017)
dateStart = "2017-05-01"
dateEnd = "2017-05-31"

#create date range
dates = pd.date_range(start=dateStart, end=dateEnd)

#loop over tiles
for tile in tiles:
    print("Downloading tile: " + tile)
#loop over dates
    for date in dates:
        print(str(date.date()) + " ...")

        #try if there is a product available for the selected date
        try:
            sentinelhub.download_safe_format(tile=(tile, str(date.date())), entire_product=True)
        except Exception as ex:
            template = "No image for the specified tile / date combination could be found."
            message = template.format(type(ex).__name__)
            print(message)

# %%
sentinelhub.download_safe_format(tile=("T33UXP", "2018-06-17"))#, entire_product=True)
# Out:
# /home/philipp/miniconda3/envs/sentinelhub/lib/python3.9/site-packages/sentinelhub/data_collections.py:614: SHDeprecationWarning: In the future please specify data_collection parameter, for now taking DataCollection.SENTINEL2_L1C
#   warnings.warn('In the future please specify data_collection parameter, for now taking '
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# ~/miniconda3/envs/sentinelhub/lib/python3.9/site-packages/sentinelhub/download/aws_client.py in _do_download(request, s3_client)
#      65         try:
# ---> 66             response = s3_client.get_object(Bucket=bucket_name, Key=url_key, RequestPayer='requester')
#      67             return response['Body'].read()
#
# ~/miniconda3/envs/sentinelhub/lib/python3.9/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     385             # The "self" in this scope is referring to the BaseClient.
# ...
