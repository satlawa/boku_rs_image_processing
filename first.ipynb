# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
path = "/home/philipp/Documents/boku/remote_sensing_and_image_processing/final_ass/training_g5/training_g5.shp"
train_pts = gpd.read_file(path)

# %%
train_pts
# Out:
#       Crop_ID_in                        geometry
# 0            1.0  POINT (627096.602 5361808.477)
# 1            1.0  POINT (631256.765 5336860.334)
# 2            1.0  POINT (637467.045 5350530.067)
# 3            1.0  POINT (624403.647 5340553.940)
# 4            1.0  POINT (623246.824 5343565.536)
# ...          ...                             ...
# 1195        15.0  POINT (614557.857 5358870.334)
# 1196        15.0  POINT (611441.750 5357183.963)
# 1197        15.0  POINT (610151.327 5357572.853)
# 1198        15.0  POINT (635975.087 5349979.032)
# 1199        15.0  POINT (637009.585 5348088.782)
#
# [1200 rows x 2 columns]

# %%
train_pts.bounds
# Out:
#                minx          miny           maxx          maxy
# 0     627096.602057  5.361808e+06  627096.602057  5.361808e+06
# 1     631256.765179  5.336860e+06  631256.765179  5.336860e+06
# 2     637467.044898  5.350530e+06  637467.044898  5.350530e+06
# 3     624403.647270  5.340554e+06  624403.647270  5.340554e+06
# 4     623246.824465  5.343566e+06  623246.824465  5.343566e+06
# ...             ...           ...            ...           ...
# 1195  614557.857178  5.358870e+06  614557.857178  5.358870e+06
# 1196  611441.750169  5.357184e+06  611441.750169  5.357184e+06
# 1197  610151.326938  5.357573e+06  610151.326938  5.357573e+06
# 1198  635975.086588  5.349979e+06  635975.086588  5.349979e+06
# 1199  637009.585022  5.348089e+06  637009.585022  5.348089e+06
#
# [1200 rows x 4 columns]

# %%
x_min = train_pts.bounds['minx'].min()
y_min = train_pts.bounds['miny'].min()
x_max = train_pts.bounds['maxx'].max()
y_max = train_pts.bounds['maxy'].max()

# %%
print(x_min, x_max)
print(y_min, y_max)
# Out:
# 605807.8840261962 646663.905254955
# 5332831.360718535 5370242.015357341

# %%
path = "/media/philipp/ed7d22ba-5a3b-4d31-bf6c-6add6e106b3d/crops/epis/march.gpkg"
fields = gpd.read_file(path)

# %%
fields.head()
# Out:
#    FS_KENNUNG SNAR_BEZEICHNUNG  SL_FLAECHE_BRUTTO_HA     GEO_ID  \
# 0  66438584.0       GRÜNBRACHE              0.223542  4335720.0
# 1  66438586.0       GRÜNBRACHE              0.701331  4335718.0
# 2  66438579.0       GRÜNBRACHE              0.983743  4335723.0
# 3  66438581.0       GRÜNBRACHE              0.842187  4468734.0
# 4  66438575.0       GRÜNBRACHE              0.326326  4335730.0
#
#                                           INSPIRE_ID  \
# 0  https://data.inspire.gv.at/0095/bdddeedb-5381-...
# 1  https://data.inspire.gv.at/0095/bdddeedb-5381-...
# 2  https://data.inspire.gv.at/0095/bdddeedb-5381-...
# 3  https://data.inspire.gv.at/0095/bdddeedb-5381-...
# 4  https://data.inspire.gv.at/0095/bdddeedb-5381-...
#
#                                               GML_ID  \
# 0  AT.0095.bdddeedb-5381-43cd-8c48-88a946ae2d0b.e...
# 1  AT.0095.bdddeedb-5381-43cd-8c48-88a946ae2d0b.e...
# 2  AT.0095.bdddeedb-5381-43cd-8c48-88a946ae2d0b.e...
# ...

# %%
new = fields[['FS_KENNUNG', 'SNAR_BEZEICHNUNG', 'SL_FLAECHE_BRUTTO_HA', 'GEO_ID', 'SNAR_CODE', 'geometry']]

# %%
new.to_file("/media/philipp/ed7d22ba-5a3b-4d31-bf6c-6add6e106b3d/crops/epis/march_new.shp")

# %%
# load shp

# %%
path = "/media/philipp/ed7d22ba-5a3b-4d31-bf6c-6add6e106b3d/crops/epis/shp2/march.shp"
fields = gpd.read_file(path)

# %%
fields.crs
# Out:
# {'init': 'epsg:31287'}

# %%
fields = fields.to_crs("EPSG:32633")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-6bc05ffdeaf6> in <module>
# ----> 1 fields = fields.to_crs("EPSG:32633")
#
# ~/miniconda3/envs/geo/lib/python3.8/site-packages/geopandas/geodataframe.py in to_crs(self, crs, epsg, inplace)
#     532         else:
#     533             df = self.copy()
# --> 534         geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#     535         df.geometry = geom
#     536         df.crs = geom.crs
#
# ~/miniconda3/envs/geo/lib/python3.8/site-packages/geopandas/geoseries.py in to_crs(self, crs, epsg)
#     422         else:
#     423             proj_in = pyproj.Proj(self.crs, preserve_units=True)
# --> 424             proj_out = pyproj.Proj(crs, preserve_units=True)
#     425             project = partial(pyproj.transform, proj_in, proj_out)
#     426         result = self.apply(lambda geom: transform(project, geom))
#
# ...
